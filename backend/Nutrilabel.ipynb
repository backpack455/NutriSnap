# %%
import re
from google.cloud import vision
import os

key_file_path = "visionkey.json"
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] ='visionkey.json'

picturepath = "label1.jpg"

nutrition_patterns = [
    ('Calories'),
    ('Total Fat'),
    ('Saturated Fat'),
    ('Trans Fat'),
    ('Cholesterol'),
    ('Sodium'),
    ('Total Carbs'),
    ('Dietary Fiber'),
    ('Sugars'),
    ('Protein'),
    ('Vitamin D'),
    ('Calcium'),
    ('Iron')
]

#Google Cloud
def detect_text(path):
    """Detects text in the file."""
    from google.cloud import vision

    client = vision.ImageAnnotatorClient()

    with open(picturepath, "rb") as image_file:
        content = image_file.read()

    image = vision.Image(content=content)
   
    response = client.text_detection(image=image)
    texts = response.text_annotations
    #print("Texts:")

    for text in texts:

        text = text.description
        print(text)
        
        #vertices = [
        #    f"({vertex.x},{vertex.y})" for vertex in text.bounding_poly.vertices
        #]

        #print("bounds: {}".format(",".join(vertices)))

    if response.error.message:
        raise Exception(
            "{}\nFor more info on error messages, check: "
            "https://cloud.google.com/apis/design/errors".format(response.error.message)
        )
  
#in extracted text, store the text that the Vision AI has extracted
extracted_text = detect_text(picturepath)
# Out:
# <class 'google.cloud.vision_v1.types.image_annotator.Image'>
# 00.
# Nutrition
# Serving Size
# Servings Per Container
# Amount Per Serving
# Calories 210
# Total Fat 7g
# Saturated Fat 2.5g
# Trans Fat Og
# Polyunsaturated Fat 2.5g
# Monounsaturated Fat 1.5g
# Cholesterol Omg
# Sodium 170mg
# Total Carbohydrate 35g
# Dietary Fiber less than 1g
# Sugars 15g
# Protein 2g
# .
# Calories from Fat 60
# % Daily Value*
# 11%
# 13%
# Total Fat
# Saturated Fat
# Facts allong's
# 1 Pastry (50g)
# 8
# Vitamin A 10% Vitamin C 0% Calcium 10%
# .
# Thiamin 10% Riboflavin 10% Niacin 10%
# Less than
# Less than
# than
# .
# 65g
# *Percent Daily Values are based on a 2,000 calorie diet. Your daily
# values may be higher or lower depending on your calorie needs:
# 2.500
# 2,000
# Calories
# 80g
# 250
# 300mp
# 400m
# 200
# .
# 300mg
# 0%
# 7%
# 12%
# 3%
# Iron
# 10%
# Vitamin Be 10%
# Pop.
# tarts
# toaster pastriel
# Og Trans Fat
# Good
# Source of
# Calcium
# 00
# .
# Nutrition
# Serving
# Size
# ...
